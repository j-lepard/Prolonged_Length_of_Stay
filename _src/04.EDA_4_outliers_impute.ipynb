# %%
import pandas as pd

# %% [markdown]
# # Feature Engineering

# %%
df=pd.read_csv('../_data/operations_inscope_CATEGORIES.csv',index_col=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102291 entries, 0 to 128030
# Data columns (total 58 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   op_id              102291 non-null  int64
#  1   subject_id         102291 non-null  int64
#  2   hadm_id            102291 non-null  int64
#  3   opdate             102291 non-null  int64
#  4   age                102291 non-null  int64
#  5   sex                102291 non-null  object
#  6   weight             101186 non-null  float64
#  7   height             101650 non-null  float64
#  8   race               102291 non-null  object
#  9   asa                99438 non-null   float64
#  10  emop               102291 non-null  int64
#  11  department         102291 non-null  object
#  12  antype             102291 non-null  object
#  13  icd10_pcs          102291 non-null  object
#  14  category_desc      102291 non-null  object
#  15  desc_short         102291 non-null  object
#  16  category_id        102291 non-null  object
#  17  orin_time          102291 non-null  int64
#  18  orout_time         102291 non-null  int64
#  19  opstart_time       102281 non-null  float64
#  20  opend_time         102281 non-null  float64
#  21  admission_time     102291 non-null  int64
#  22  discharge_time     102291 non-null  int64
#  23  anstart_time       102247 non-null  float64
#  24  anend_time         102013 non-null  float64
#  25  cpbon_time         2451 non-null    float64
#  26  cpboff_time        2451 non-null    float64
#  27  icuin_time         13772 non-null   float64
#  28  icuout_time        13772 non-null   float64
#  29  inhosp_death_time  1392 non-null    float64
#  30  subject_id_y       102265 non-null  float64
#  31  chart_time_x       102265 non-null  float64
#  32  art_dbp            30084 non-null   float64
#  33  art_mbp            30769 non-null   float64
#  34  art_sbp            30154 non-null   float64
#  35  bt                 22491 non-null   float64
#  36  cvp                2425 non-null    float64
#  37  hr                 88530 non-null   float64
#  38  pip                65537 non-null   float64
#  39  pmean              61835 non-null   float64
#  40  rr                 77270 non-null   float64
#  41  spo2               92483 non-null   float64
#  42  vt                 66920 non-null   float64
#  43  chart_time_y       78552 non-null   float64
#  44  alp                29103 non-null   float64
#  45  alt                30566 non-null   float64
#  46  ast                30582 non-null   float64
#  47  chloride           37856 non-null   float64
#  48  creatinine         33665 non-null   float64
#  49  glucose            36423 non-null   float64
#  50  hb                 38057 non-null   float64
#  51  hco3               28569 non-null   float64
#  52  lymphocyte         29660 non-null   float64
#  53  platelet           36122 non-null   float64
#  54  potassium          52077 non-null   float64
#  55  sodium             51791 non-null   float64
#  56  total_bilirubin    27509 non-null   float64
#  57  wbc                35594 non-null   float64
# dtypes: float64(40), int64(10), object(8)
# memory usage: 46.0+ MB

# %% [markdown]
# ## Identify LOS Outliers within each surgery type
#
# We use `groupby`('icd10_pcs') groups the data by the unique values in the 'icd10_pcs'.
#  For each group, `transform` applies the calculate_percentile_90 function to values within that group.
#
# This group-specific 90th percentile is then used to determine if a value is an outlier within its category.
# Lastly, the is_outlier column is created to indicate with 1 if the record is an outlier in its category or 0 otherwise. We also clean up by dropping the intermediate 'percentile_90' column.

# %%
import pandas as pd
import numpy as np

# Assuming df is your DataFrame, 'column_name' is the column you're examining,
# and 'category_column' is the column with the categorical data
df['LOS']=(df['discharge_time']-df['orout_time'])/1440 # LOS is time following surgery to dishcarge converted to days. 

# Define a function to calculate the 75th percentile for a series
def calculate_percentile_75(series):
    return series.quantile(0.90)

# Apply the function to each group's 'icd10_pcs' and create a new column for the 75th percentile
df['percentile_90'] = df.groupby('icd10_pcs')['LOS'].transform(calculate_percentile_75)

# Create a new column with 0/1 based on the condition, using the group-specific 75th percentile
df['is_outlier'] = np.where(df['LOS'] > df['percentile_90'], 1, 0)

# Drop the 'percentile_75' column if it's no longer needed
df.drop('percentile_90', axis=1, inplace=True)

df
# Out:
#             op_id  subject_id    hadm_id   opdate  age sex  weight  height  \
# 0       484069807   178742874  229842382        0   30   F    48.0   153.0
# 1       446270725   158995752  257857903        0   70   M    43.0   169.0
# 2       478413008   133278262  277235295        0   35   F    54.0     NaN
# 7       466411896   100259714  241547739     1440   50   F    66.0   157.0
# 8       467425045   134213281  225860669     1440   60   F    62.0   154.0
# ...           ...         ...        ...      ...  ...  ..     ...     ...
# 128026  449124488   138484174  228449654  4999680   50   F    58.0   162.0
# 128027  461252752   126772283  273139806     2880   70   F    53.0   162.0
# 128028  471834474   144363433  275833861     2880   65   F    51.0   152.0
# 128029  419787421   195835964  293939099    12960   85   M    74.0   171.0
# 128030  493136728   148443464  280269654     2880   70   M    78.0   182.0
#
#          race  asa  ...    hb  hco3 lymphocyte platelet potassium sodium  \
# 0       Asian  NaN  ...   8.7   NaN       27.2    232.0       4.2  138.0
# 1       Asian  NaN  ...  11.0  18.0       38.1    124.0       4.2  140.0
# 2       Asian  NaN  ...  12.7   NaN        8.3    244.0       NaN    NaN
# 7       Asian  2.0  ...   NaN   NaN        NaN      NaN       NaN    NaN
# 8       Asian  1.0  ...   NaN   NaN        NaN      NaN       NaN    NaN
# ...       ...  ...  ...   ...   ...        ...      ...       ...    ...
# 128026  Asian  2.0  ...   NaN  23.7        NaN      NaN       3.8  134.0
# 128027  Asian  2.0  ...   NaN   NaN        NaN      NaN       3.7  142.0
# 128028  Asian  2.0  ...   NaN   NaN        NaN      NaN       3.8  143.0
# 128029  Asian  4.0  ...   NaN  22.6        NaN      NaN       3.9  137.0
# 128030  Asian  2.0  ...   NaN   NaN        NaN      NaN       NaN    NaN
#
#        total_bilirubin    wbc        LOS  is_outlier
# 0                  NaN   5.62   4.131944           0
# 1                  0.5    NaN  47.920139           1
# 2                  NaN  17.62   3.760417           0
# 7                  NaN    NaN   2.447917           0
# 8                  NaN    NaN   3.493056           0
# ...                ...    ...        ...         ...
# 128026             NaN    NaN   8.378472           0
# 128027             NaN    NaN   2.614583           0
# 128028             NaN    NaN   5.447917           0
# 128029             NaN    NaN   9.309028           0
# 128030             NaN    NaN   1.614583           0
#
# [102291 rows x 60 columns]

# %% [markdown]
# ### Classify if LOS was "Prolonged"
# * set business rule as Prolonged is an LOS that is greater 1 std dev than the average.

# %%
import pandas as pd
import numpy as np

# Define functions to calculate the mean and standard deviation for a series
def calculate_mean(series):
    return series.mean()

def calculate_std(series):
    return series.std()

# Apply the functions to each group's 'column_name' to create new columns for the mean and standard deviation
df['group_mean'] = df.groupby('icd10_pcs')['LOS'].transform(calculate_mean)
df['group_std'] = df.groupby('icd10_pcs')['LOS'].transform(calculate_std)

# Define one standard deviation away from the mean
df['mean_plus_std'] = df['group_mean'] + df['group_std']

# Create a new column with 0/1 based on the condition, 
# using the group-specific mean and standard deviation
df['prolonged_LOS'] = np.where(df['LOS'] > df['group_std'], 1, 0)

# Drop the 'group_mean' and 'group_std' columns if they're no longer needed
df.drop(['group_mean', 'group_std', 'mean_plus_std'], axis=1, inplace=True)
df
# Optionally, if you still need the filtered DataFrame without outliers, you can filter the DataFrame
# df_filtered = df[(df['prolonged_LOS'] == 1 )&(df['is_outlier'] == 0) ]
# df_filtered
# Out:
#             op_id  subject_id    hadm_id   opdate  age sex  weight  height  \
# 0       484069807   178742874  229842382        0   30   F    48.0   153.0
# 1       446270725   158995752  257857903        0   70   M    43.0   169.0
# 2       478413008   133278262  277235295        0   35   F    54.0     NaN
# 7       466411896   100259714  241547739     1440   50   F    66.0   157.0
# 8       467425045   134213281  225860669     1440   60   F    62.0   154.0
# ...           ...         ...        ...      ...  ...  ..     ...     ...
# 128026  449124488   138484174  228449654  4999680   50   F    58.0   162.0
# 128027  461252752   126772283  273139806     2880   70   F    53.0   162.0
# 128028  471834474   144363433  275833861     2880   65   F    51.0   152.0
# 128029  419787421   195835964  293939099    12960   85   M    74.0   171.0
# 128030  493136728   148443464  280269654     2880   70   M    78.0   182.0
#
#          race  asa  ...  hco3 lymphocyte platelet potassium sodium  \
# 0       Asian  NaN  ...   NaN       27.2    232.0       4.2  138.0
# 1       Asian  NaN  ...  18.0       38.1    124.0       4.2  140.0
# 2       Asian  NaN  ...   NaN        8.3    244.0       NaN    NaN
# 7       Asian  2.0  ...   NaN        NaN      NaN       NaN    NaN
# 8       Asian  1.0  ...   NaN        NaN      NaN       NaN    NaN
# ...       ...  ...  ...   ...        ...      ...       ...    ...
# 128026  Asian  2.0  ...  23.7        NaN      NaN       3.8  134.0
# 128027  Asian  2.0  ...   NaN        NaN      NaN       3.7  142.0
# 128028  Asian  2.0  ...   NaN        NaN      NaN       3.8  143.0
# 128029  Asian  4.0  ...  22.6        NaN      NaN       3.9  137.0
# 128030  Asian  2.0  ...   NaN        NaN      NaN       NaN    NaN
#
#        total_bilirubin    wbc        LOS  is_outlier  prolonged_LOS
# 0                  NaN   5.62   4.131944           0              0
# 1                  0.5    NaN  47.920139           1              1
# 2                  NaN  17.62   3.760417           0              1
# 7                  NaN    NaN   2.447917           0              1
# 8                  NaN    NaN   3.493056           0              1
# ...                ...    ...        ...         ...            ...
# 128026             NaN    NaN   8.378472           0              0
# 128027             NaN    NaN   2.614583           0              1
# 128028             NaN    NaN   5.447917           0              1
# 128029             NaN    NaN   9.309028           0              1
# 128030             NaN    NaN   1.614583           0              0
#
# [102291 rows x 61 columns]

# %%
df

# %% [markdown]
# ## Identify Subject that had ICU visit (and duration)

# %%
## Create flag if subject went to ICU

df['icu_visit'] = (df['icuin_time'] > 0).astype(int)
df[df['icu_visit']== True]

# df['ICU_dur']= (df['icuout_time']-df['icuin_time'])
# Elected to omit ICR duration as most are Nan and woud increase complexity to drop later.

## 13771  subjects went to ICU post op.
# Out:
#             op_id  subject_id    hadm_id   opdate  age sex  weight  height  \
# 1       446270725   158995752  257857903        0   70   M    43.0   169.0
# 12      487807079   145247513  259299532    74880   25   M    47.0   172.0
# 20      480242953   187733661  238035661    10080   55   F    46.0   152.0
# 22      485183540   160631734  285012362     1440   70   M    68.0   172.0
# 27      432945014   126077562  272790506     2880   50   F    61.0   149.0
# ...           ...         ...        ...      ...  ...  ..     ...     ...
# 127986  494319208   150497300  289152391  3483360   80   F    52.0   150.0
# 127989  474723417   152774881  253900635    14400   80   F    66.0   145.0
# 127993  468666428   137181591  298918264     5760   65   F    61.0   158.0
# 128008  465468763   150497300  289152391  3483360   80   F    52.0   150.0
# 128029  419787421   195835964  293939099    12960   85   M    74.0   171.0
#
#          race  asa  ...  lymphocyte platelet potassium sodium total_bilirubin  \
# 1       Asian  NaN  ...        38.1    124.0       4.2  140.0             0.5
# 12      Asian  2.0  ...         NaN      NaN       NaN    NaN             NaN
# 20      Asian  2.0  ...         NaN      NaN       3.3  139.0             NaN
# 22      Asian  3.0  ...         NaN      NaN       4.1  139.0             NaN
# 27      Asian  2.0  ...         NaN      NaN       NaN    NaN             3.8
# ...       ...  ...  ...         ...      ...       ...    ...             ...
# 127986  Asian  4.0  ...        10.6    227.0       3.3  141.0             0.5
# 127989  Asian  3.0  ...         NaN      NaN       3.5  143.0             NaN
# 127993  Asian  2.0  ...         NaN      NaN       3.5  136.0             NaN
# 128008  Asian  4.0  ...        10.6    227.0       3.3  141.0             0.5
# 128029  Asian  4.0  ...         NaN      NaN       3.9  137.0             NaN
#
#           wbc        LOS  is_outlier  prolonged_LOS  icu_visit
# 1         NaN  47.920139           1              1          1
# 12        NaN  23.131944           1              0          1
# 20        NaN  16.302083           0              0          1
# 22        NaN   6.295139           0              0          1
# 27        NaN  17.305556           0              0          1
# ...       ...        ...         ...            ...        ...
# 127986  15.79  60.829861           1              1          1
# 127989    NaN   8.111111           0              0          1
# 127993    NaN   7.152778           0              0          1
# 128008  15.79  61.020833           1              1          1
# 128029    NaN   9.309028           0              1          1
#
# [13771 rows x 62 columns]

# %%
#########################
#
# Calculate OR Duration and Anesthetic Duration
#
#########################

#Operation Duration
df['or_duration']=(df['opend_time']-df['opstart_time'])

#Time under anasthetic
df['anesth_duration']=(df['anend_time']-df['anstart_time'])

df
# Out:
#             op_id  subject_id    hadm_id   opdate  age sex  weight  height  \
# 0       484069807   178742874  229842382        0   30   F    48.0   153.0
# 1       446270725   158995752  257857903        0   70   M    43.0   169.0
# 2       478413008   133278262  277235295        0   35   F    54.0     NaN
# 7       466411896   100259714  241547739     1440   50   F    66.0   157.0
# 8       467425045   134213281  225860669     1440   60   F    62.0   154.0
# ...           ...         ...        ...      ...  ...  ..     ...     ...
# 128026  449124488   138484174  228449654  4999680   50   F    58.0   162.0
# 128027  461252752   126772283  273139806     2880   70   F    53.0   162.0
# 128028  471834474   144363433  275833861     2880   65   F    51.0   152.0
# 128029  419787421   195835964  293939099    12960   85   M    74.0   171.0
# 128030  493136728   148443464  280269654     2880   70   M    78.0   182.0
#
#          race  asa  ...  potassium sodium total_bilirubin    wbc        LOS  \
# 0       Asian  NaN  ...        4.2  138.0             NaN   5.62   4.131944
# 1       Asian  NaN  ...        4.2  140.0             0.5    NaN  47.920139
# 2       Asian  NaN  ...        NaN    NaN             NaN  17.62   3.760417
# 7       Asian  2.0  ...        NaN    NaN             NaN    NaN   2.447917
# 8       Asian  1.0  ...        NaN    NaN             NaN    NaN   3.493056
# ...       ...  ...  ...        ...    ...             ...    ...        ...
# 128026  Asian  2.0  ...        3.8  134.0             NaN    NaN   8.378472
# 128027  Asian  2.0  ...        3.7  142.0             NaN    NaN   2.614583
# 128028  Asian  2.0  ...        3.8  143.0             NaN    NaN   5.447917
# 128029  Asian  4.0  ...        3.9  137.0             NaN    NaN   9.309028
# 128030  Asian  2.0  ...        NaN    NaN             NaN    NaN   1.614583
#
#        is_outlier prolonged_LOS  icu_visit  or_duration  anesth_duration
# 0               0             0          0         90.0            115.0
# 1               1             1          1        170.0            195.0
# 2               0             1          0        100.0            125.0
# 7               0             1          0         45.0             70.0
# 8               0             1          0         70.0             90.0
# ...           ...           ...        ...          ...              ...
# 128026          0             0          0        160.0            180.0
# 128027          0             1          0         60.0             75.0
# 128028          0             1          0         55.0             75.0
# 128029          0             1          1        130.0            170.0
# 128030          0             0          0         55.0             70.0
#
# [102291 rows x 64 columns]

# %%
## Drop extra column. Exclude Outliers from further analysis. 
cols_to_drop = ['is_outlier', 'art_dbp','chart_time_y','chart_time_x','inhosp_death_time','orin_time', 'orout_time', 'opstart_time', 'opend_time','admission_time', 'discharge_time','anstart_time' ,'anend_time', 'cpbon_time','cpboff_time','icuin_time','icuout_time', 'subject_id_y', 'chart_time_x','art_mbp','art_sbp','art_sbp','bt','cvp','alp','alt','ast', 'emop']
df = df[df['is_outlier'] == 0 ]
df = df.drop(columns=cols_to_drop)

df
# Out:
#             op_id  subject_id    hadm_id   opdate  age sex  weight  height  \
# 0       484069807   178742874  229842382        0   30   F    48.0   153.0
# 2       478413008   133278262  277235295        0   35   F    54.0     NaN
# 7       466411896   100259714  241547739     1440   50   F    66.0   157.0
# 8       467425045   134213281  225860669     1440   60   F    62.0   154.0
# 9       461473883   134195201  265770645     1440   35   F    50.0   160.0
# ...           ...         ...        ...      ...  ...  ..     ...     ...
# 128026  449124488   138484174  228449654  4999680   50   F    58.0   162.0
# 128027  461252752   126772283  273139806     2880   70   F    53.0   162.0
# 128028  471834474   144363433  275833861     2880   65   F    51.0   152.0
# 128029  419787421   195835964  293939099    12960   85   M    74.0   171.0
# 128030  493136728   148443464  280269654     2880   70   M    78.0   182.0
#
#          race  asa  ... platelet potassium sodium total_bilirubin    wbc  \
# 0       Asian  NaN  ...    232.0       4.2  138.0             NaN   5.62
# 2       Asian  NaN  ...    244.0       NaN    NaN             NaN  17.62
# 7       Asian  2.0  ...      NaN       NaN    NaN             NaN    NaN
# 8       Asian  1.0  ...      NaN       NaN    NaN             NaN    NaN
# 9       Asian  1.0  ...    124.0       3.9  138.0             0.6   6.31
# ...       ...  ...  ...      ...       ...    ...             ...    ...
# 128026  Asian  2.0  ...      NaN       3.8  134.0             NaN    NaN
# 128027  Asian  2.0  ...      NaN       3.7  142.0             NaN    NaN
# 128028  Asian  2.0  ...      NaN       3.8  143.0             NaN    NaN
# 128029  Asian  4.0  ...      NaN       3.9  137.0             NaN    NaN
# 128030  Asian  2.0  ...      NaN       NaN    NaN             NaN    NaN
#
#              LOS  prolonged_LOS  icu_visit  or_duration  anesth_duration
# 0       4.131944              0          0         90.0            115.0
# 2       3.760417              1          0        100.0            125.0
# 7       2.447917              1          0         45.0             70.0
# 8       3.493056              1          0         70.0             90.0
# 9       4.236111              0          0        115.0            150.0
# ...          ...            ...        ...          ...              ...
# 128026  8.378472              0          0        160.0            180.0
# 128027  2.614583              1          0         60.0             75.0
# 128028  5.447917              1          0         55.0             75.0
# 128029  9.309028              1          1        130.0            170.0
# 128030  1.614583              0          0         55.0             70.0
#
# [91862 rows x 38 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91862 entries, 0 to 128030
# Data columns (total 38 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   op_id            91862 non-null  int64
#  1   subject_id       91862 non-null  int64
#  2   hadm_id          91862 non-null  int64
#  3   opdate           91862 non-null  int64
#  4   age              91862 non-null  int64
#  5   sex              91862 non-null  object
#  6   weight           90910 non-null  float64
#  7   height           91326 non-null  float64
#  8   race             91862 non-null  object
#  9   asa              89532 non-null  float64
#  10  department       91862 non-null  object
#  11  antype           91862 non-null  object
#  12  icd10_pcs        91862 non-null  object
#  13  category_desc    91862 non-null  object
#  14  desc_short       91862 non-null  object
#  15  category_id      91862 non-null  object
#  16  hr               79842 non-null  float64
#  17  pip              58613 non-null  float64
#  18  pmean            55459 non-null  float64
#  19  rr               69118 non-null  float64
#  20  spo2             83449 non-null  float64
#  21  vt               59666 non-null  float64
#  22  chloride         33612 non-null  float64
#  23  creatinine       29762 non-null  float64
#  24  glucose          32099 non-null  float64
#  25  hb               33656 non-null  float64
#  26  hco3             25068 non-null  float64
#  27  lymphocyte       26070 non-null  float64
#  28  platelet         32019 non-null  float64
#  29  potassium        45995 non-null  float64
#  30  sodium           45752 non-null  float64
#  31  total_bilirubin  24302 non-null  float64
#  32  wbc              31531 non-null  float64
#  33  LOS              91862 non-null  float64
#  34  prolonged_LOS    91862 non-null  int32
#  35  icu_visit        91862 non-null  int32
#  36  or_duration      91852 non-null  float64
#  37  anesth_duration  91612 non-null  float64
# dtypes: float64(23), int32(2), int64(5), object(8)
# memory usage: 26.6+ MB

# %% [markdown]
# ## Impute Medians for Missing Data
# * cannot impute means across the whole data set (mix of male, female, age)
# * means are imputed within each category (group be: sex, age, race)
# * Note: this step is not performed in teh pipelines as important to find means for each 'group' of subject (ie: find mean platlet count for same gender, same age, same ASA)

# %%
## Confirm the column index that you want to include in the imput calcs.
df.info()

# %%
import pandas as pd
import numpy as np

# df_no_outlier = df[df['is_outlier'] == 0]
# Range to evaluate columns 32:58 (inclusive)

category_columns = ['age', 'sex', 'asa']  # asa is the id from Amercican Society of Anthropologists.
start_col = 17  # Start index 
end_col = 34    # End index (exclusive) 

# Iterate over each column in the specified range and apply groupby and transform
for col in df.iloc[:, start_col:end_col].columns:
    # Group by the categorical columns and fill NaN with the mean of the group for each specific column
    df[col] = df.groupby(category_columns)[col].transform(lambda x: x.fillna(x.mean()))

# Now df has the missing values imputed with the mean of their respective column within each group defined by 'category_columns'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91862 entries, 0 to 128030
# Data columns (total 38 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   op_id            91862 non-null  int64
#  1   subject_id       91862 non-null  int64
#  2   hadm_id          91862 non-null  int64
#  3   opdate           91862 non-null  int64
#  4   age              91862 non-null  int64
#  5   sex              91862 non-null  object
#  6   weight           90910 non-null  float64
#  7   height           91326 non-null  float64
#  8   race             91862 non-null  object
#  9   asa              89532 non-null  float64
#  10  department       91862 non-null  object
#  11  antype           91862 non-null  object
#  12  icd10_pcs        91862 non-null  object
#  13  category_desc    91862 non-null  object
#  14  desc_short       91862 non-null  object
#  15  category_id      91862 non-null  object
#  16  hr               79842 non-null  float64
#  17  pip              89519 non-null  float64
#  18  pmean            89508 non-null  float64
#  19  rr               89517 non-null  float64
#  20  spo2             89517 non-null  float64
#  21  vt               89512 non-null  float64
#  22  chloride         89471 non-null  float64
#  23  creatinine       89467 non-null  float64
#  24  glucose          89527 non-null  float64
#  25  hb               89488 non-null  float64
#  26  hco3             89520 non-null  float64
#  27  lymphocyte       89460 non-null  float64
#  28  platelet         89461 non-null  float64
#  29  potassium        89523 non-null  float64
#  30  sodium           89522 non-null  float64
#  31  total_bilirubin  89454 non-null  float64
#  32  wbc              89465 non-null  float64
#  33  LOS              89532 non-null  float64
#  34  prolonged_LOS    91862 non-null  int32
#  35  icu_visit        91862 non-null  int32
#  36  or_duration      91852 non-null  float64
#  37  anesth_duration  91612 non-null  float64
# dtypes: float64(23), int32(2), int64(5), object(8)
# memory usage: 26.6+ MB

# %%
df = df.dropna()
df.shape
# Out:
# (76742, 38)

# %%
#########################
#
# Data EXport 
#
#########################
df.to_csv('../_data/operations_imputed_CLEAN_v2.csv')
