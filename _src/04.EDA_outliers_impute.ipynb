# %%
import pandas as pd

# %% [markdown]
# # Feature Engineering

# %%
df=pd.read_csv('../_data/operations_inscope.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58815 entries, 0 to 58814
# Data columns (total 58 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   op_id              58815 non-null  int64
#  1   subject_id         58815 non-null  int64
#  2   hadm_id            58815 non-null  int64
#  3   opdate             58815 non-null  int64
#  4   age                58815 non-null  int64
#  5   sex                58815 non-null  object
#  6   weight             58180 non-null  float64
#  7   height             58461 non-null  float64
#  8   race               58815 non-null  object
#  9   asa                56842 non-null  float64
#  10  emop               58815 non-null  int64
#  11  department         58815 non-null  object
#  12  antype             58815 non-null  object
#  13  icd10_pcs          58815 non-null  object
#  14  category_desc      58815 non-null  object
#  15  desc_short         58815 non-null  object
#  16  category_id        58815 non-null  object
#  17  orin_time          58815 non-null  int64
#  18  orout_time         58815 non-null  int64
#  19  opstart_time       58811 non-null  float64
#  20  opend_time         58813 non-null  float64
#  21  admission_time     58815 non-null  int64
#  22  discharge_time     58815 non-null  int64
#  23  anstart_time       58783 non-null  float64
#  24  anend_time         58631 non-null  float64
#  25  cpbon_time         707 non-null    float64
#  26  cpboff_time        707 non-null    float64
#  27  icuin_time         7251 non-null   float64
#  28  icuout_time        7251 non-null   float64
#  29  inhosp_death_time  882 non-null    float64
#  30  subject_id_y       58794 non-null  float64
#  31  chart_time_x       58794 non-null  float64
#  32  art_dbp            12921 non-null  float64
#  33  art_mbp            13251 non-null  float64
#  34  art_sbp            12958 non-null  float64
#  35  bt                 12508 non-null  float64
#  36  cvp                990 non-null    float64
#  37  hr                 51399 non-null  float64
#  38  pip                37131 non-null  float64
#  39  pmean              33125 non-null  float64
#  40  rr                 43083 non-null  float64
#  41  spo2               53632 non-null  float64
#  42  vt                 37253 non-null  float64
#  43  chart_time_y       41310 non-null  float64
#  44  alp                12415 non-null  float64
#  45  alt                12848 non-null  float64
#  46  ast                12850 non-null  float64
#  47  chloride           18239 non-null  float64
#  48  creatinine         14419 non-null  float64
#  49  glucose            17416 non-null  float64
#  50  hb                 17773 non-null  float64
#  51  hco3               14035 non-null  float64
#  52  lymphocyte         14662 non-null  float64
#  53  platelet           16649 non-null  float64
#  54  potassium          23970 non-null  float64
#  55  sodium             23795 non-null  float64
#  56  total_bilirubin    11484 non-null  float64
#  57  wbc                16347 non-null  float64
# dtypes: float64(40), int64(10), object(8)
# memory usage: 26.0+ MB

# %% [markdown]
# ## Identify LOS Outliers within each surgery type
#
# We use `groupby`('icd10_pcs') groups the data by the unique values in the 'icd10_pcs'.
#  For each group, `transform` applies the calculate_percentile_75 function to values within that group.
#  This group-specific 75th percentile is then used to determine if a value is an outlier within its category.
#
# Lastly, the is_outlier column is created to indicate with 1 if the record is an outlier in its category or 0 otherwise. We also clean up by dropping the intermediate 'percentile_75' column.

# %%
import pandas as pd
import numpy as np

# Assuming df is your DataFrame, 'column_name' is the column you're examining,
# and 'category_column' is the column with the categorical data
df['LOS']=(df['discharge_time']-df['orout_time'])/1440 # LOS is time following surgery to dishcarge converted to days. 

# Define a function to calculate the 75th percentile for a series
def calculate_percentile_75(series):
    return series.quantile(0.75)

# Apply the function to each group's 'icd10_pcs' and create a new column for the 75th percentile
df['percentile_75'] = df.groupby('icd10_pcs')['LOS'].transform(calculate_percentile_75)

# Create a new column with 0/1 based on the condition, using the group-specific 75th percentile
df['is_outlier'] = np.where(df['LOS'] > df['percentile_75'], 1, 0)

# Drop the 'percentile_75' column if it's no longer needed
df.drop('percentile_75', axis=1, inplace=True)

df
# Optionally, if you still need the filtered DataFrame without outliers, you can filter the DataFrame
# Out:
#            op_id  subject_id    hadm_id   opdate  age sex  weight  height  \
# 0      446270725   158995752  257857903        0   70   M    43.0   169.0
# 1      478413008   133278262  277235295        0   35   F    54.0     NaN
# 2      467425045   134213281  225860669     1440   60   F    62.0   154.0
# 3      461473883   134195201  265770645     1440   35   F    50.0   160.0
# 4      466389608   160947402  262240911     1440   60   F    52.0   152.0
# ...          ...         ...        ...      ...  ...  ..     ...     ...
# 58810  497537801   130062652  263988404  3909600   50   M    64.0   169.0
# 58811  461252752   126772283  273139806     2880   70   F    53.0   162.0
# 58812  471834474   144363433  275833861     2880   65   F    51.0   152.0
# 58813  419787421   195835964  293939099    12960   85   M    74.0   171.0
# 58814  493136728   148443464  280269654     2880   70   M    78.0   182.0
#
#         race  asa  ...    hb  hco3 lymphocyte platelet potassium sodium  \
# 0      Asian  NaN  ...  11.0  18.0       38.1    124.0       4.2  140.0
# 1      Asian  NaN  ...  12.7   NaN        8.3    244.0       NaN    NaN
# 2      Asian  1.0  ...   NaN   NaN        NaN      NaN       NaN    NaN
# 3      Asian  1.0  ...  10.4   NaN       13.3    124.0       3.9  138.0
# 4      Asian  1.0  ...   NaN   NaN        NaN      NaN       NaN    NaN
# ...      ...  ...  ...   ...   ...        ...      ...       ...    ...
# 58810  Asian  2.0  ...   NaN   NaN        NaN      NaN       3.5  136.0
# 58811  Asian  2.0  ...   NaN   NaN        NaN      NaN       3.7  142.0
# 58812  Asian  2.0  ...   NaN   NaN        NaN      NaN       3.8  143.0
# 58813  Asian  4.0  ...   NaN  22.6        NaN      NaN       3.9  137.0
# 58814  Asian  2.0  ...   NaN   NaN        NaN      NaN       NaN    NaN
#
#       total_bilirubin    wbc        LOS  is_outlier
# 0                 0.5    NaN  47.920139           1
# 1                 NaN  17.62   3.760417           0
# 2                 NaN    NaN   3.493056           0
# 3                 0.6   6.31   4.236111           0
# 4                 NaN    NaN   1.607639           0
# ...               ...    ...        ...         ...
# 58810             NaN    NaN   1.447917           0
# 58811             NaN    NaN   2.614583           0
# 58812             NaN    NaN   5.447917           0
# 58813             NaN    NaN   9.309028           1
# 58814             NaN    NaN   1.614583           0
#
# [58815 rows x 60 columns]

# %% [markdown]
# ## Identify Subject that had ICU visit

# %%
## Create flag if subject went to ICU

df['icu_visit'] = (df['icuin_time'] > 0).astype(int)
df[df['icu_visit']== True]

## 7250 subjects went to ICU post op.
# Out:
#            op_id  subject_id    hadm_id   opdate  age sex  weight  height  \
# 0      446270725   158995752  257857903        0   70   M    43.0   169.0
# 5      487807079   145247513  259299532    74880   25   M    47.0   172.0
# 13     480242953   187733661  238035661    10080   55   F    46.0   152.0
# 17     432945014   126077562  272790506     2880   50   F    61.0   149.0
# 18     461524976   194549663  293384214     2880   50   M    75.0   171.0
# ...          ...         ...        ...      ...  ...  ..     ...     ...
# 58794  475125418   128375644  289406001    24480   50   F    61.0   155.0
# 58795  486837329   104340242  298141008   105120   65   M    48.0   161.0
# 58802  447857589   163754043  274747413    11520   70   M    59.0   168.0
# 58803  494319208   150497300  289152391  3483360   80   F    52.0   150.0
# 58813  419787421   195835964  293939099    12960   85   M    74.0   171.0
#
#         race  asa  ...    platelet potassium      sodium total_bilirubin  \
# 0      Asian  NaN  ...         NaN       NaN         NaN             NaN
# 5      Asian  2.0  ...  244.000000  4.001266  138.897436        0.822807
# 13     Asian  2.0  ...  218.004494  3.300000  139.000000        0.797994
# 17     Asian  2.0  ...  228.864230  3.841283  139.555034        3.800000
# 18     Asian  2.0  ...  199.367424  4.300000  132.000000        1.132530
# ...      ...  ...  ...         ...       ...         ...             ...
# 58794  Asian  3.0  ...  204.026316  4.300000  135.000000        1.490323
# 58795  Asian  4.0  ...  144.000000  4.105000  135.050000        1.861538
# 58802  Asian  4.0  ...  153.666667  5.200000  135.000000        1.309091
# 58803  Asian  4.0  ...  227.000000  3.300000  141.000000        0.500000
# 58813  Asian  4.0  ...  164.000000  3.900000  137.000000        1.800000
#
#              wbc         LOS is_outlier  icu_visit  or_duration  \
# 0            NaN         NaN          1          1        170.0
# 5       9.888197   23.131944          1          1         25.0
# 13      8.319523   16.302083          0          1        455.0
# 17      8.571333   17.305556          0          1        425.0
# 18      9.246938   11.069444          0          1        430.0
# ...          ...         ...        ...        ...          ...
# 58794   9.317778   18.312500          0          1         30.0
# 58795   7.880769  106.173611          1          1         45.0
# 58802   9.741538   15.361111          1          1        265.0
# 58803  15.790000   60.829861          1          1        225.0
# 58813   9.695000    9.309028          1          1        130.0
#
#        anesth_duration
# 0                195.0
# 5                 55.0
# 13               510.0
# 17               485.0
# 18               460.0
# ...                ...
# 58794             55.0
# 58795             65.0
# 58802            315.0
# 58803            265.0
# 58813            170.0
#
# [7250 rows x 63 columns]

# %%
#########################
#
# Calculate OR Duration and Anesthetic Duration
#
#########################

#Operation Duration
df['or_duration']=(df['opend_time']-df['opstart_time'])

#Time under anasthetic
df['anesth_duration']=(df['anend_time']-df['anstart_time'])

# %% [markdown]
# ## Impute Medians for Missing Data
# * cannot impute means across the whole data set (mix of male, female, age)
# * means are imputed within each category (group be: sex, age, race)

# %%
import pandas as pd
import numpy as np

# df_no_outlier = df[df['is_outlier'] == 0]
# Range to evaluate columns 32:58 (inclusive)

category_columns = ['age', 'sex', 'asa']  # asa is the id from Amercican Society of Anthropologists.
start_col = 33  # Start index 
end_col = 59    # End index (exclusive) 

# Iterate over each column in the specified range and apply groupby and transform
for col in df.iloc[:, start_col:end_col].columns:
    # Group by the categorical columns and fill NaN with the mean of the group for each specific column
    df[col] = df.groupby(category_columns)[col].transform(lambda x: x.fillna(x.mean()))

# Now df has the missing values imputed with the mean of their respective column within each group defined by 'category_columns'
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58815 entries, 0 to 58814
# Data columns (total 63 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   op_id              58815 non-null  int64
#  1   subject_id         58815 non-null  int64
#  2   hadm_id            58815 non-null  int64
#  3   opdate             58815 non-null  int64
#  4   age                58815 non-null  int64
#  5   sex                58815 non-null  object
#  6   weight             58180 non-null  float64
#  7   height             58461 non-null  float64
#  8   race               58815 non-null  object
#  9   asa                56842 non-null  float64
#  10  emop               58815 non-null  int64
#  11  department         58815 non-null  object
#  12  antype             58815 non-null  object
#  13  icd10_pcs          58815 non-null  object
#  14  category_desc      58815 non-null  object
#  15  desc_short         58815 non-null  object
#  16  category_id        58815 non-null  object
#  17  orin_time          58815 non-null  int64
#  18  orout_time         58815 non-null  int64
#  19  opstart_time       58811 non-null  float64
#  20  opend_time         58813 non-null  float64
#  21  admission_time     58815 non-null  int64
#  22  discharge_time     58815 non-null  int64
#  23  anstart_time       58783 non-null  float64
#  24  anend_time         58631 non-null  float64
#  25  cpbon_time         707 non-null    float64
#  26  cpboff_time        707 non-null    float64
#  27  icuin_time         7251 non-null   float64
#  28  icuout_time        7251 non-null   float64
#  29  inhosp_death_time  882 non-null    float64
#  30  subject_id_y       58794 non-null  float64
#  31  chart_time_x       58794 non-null  float64
#  32  art_dbp            12921 non-null  float64
#  33  art_mbp            56817 non-null  float64
#  34  art_sbp            56815 non-null  float64
#  35  bt                 56805 non-null  float64
#  36  cvp                56508 non-null  float64
#  37  hr                 56832 non-null  float64
#  38  pip                56833 non-null  float64
#  39  pmean              56829 non-null  float64
#  40  rr                 56833 non-null  float64
#  41  spo2               56836 non-null  float64
#  42  vt                 56830 non-null  float64
#  43  chart_time_y       56841 non-null  float64
#  44  alp                56777 non-null  float64
#  45  alt                56786 non-null  float64
#  46  ast                56786 non-null  float64
#  47  chloride           56785 non-null  float64
#  48  creatinine         56785 non-null  float64
#  49  glucose            56833 non-null  float64
#  50  hb                 56809 non-null  float64
#  51  hco3               56823 non-null  float64
#  52  lymphocyte         56795 non-null  float64
#  53  platelet           56789 non-null  float64
#  54  potassium          56825 non-null  float64
#  55  sodium             56824 non-null  float64
#  56  total_bilirubin    56776 non-null  float64
#  57  wbc                56801 non-null  float64
#  58  LOS                56842 non-null  float64
#  59  is_outlier         58815 non-null  int32
#  60  icu_visit          58815 non-null  int32
#  61  or_duration        58811 non-null  float64
#  62  anesth_duration    58631 non-null  float64
# dtypes: float64(43), int32(2), int64(10), object(8)
# memory usage: 27.8+ MB
#            op_id  subject_id    hadm_id   opdate  age sex  weight  height  \
# 0      446270725   158995752  257857903        0   70   M    43.0   169.0
# 1      478413008   133278262  277235295        0   35   F    54.0     NaN
# 2      467425045   134213281  225860669     1440   60   F    62.0   154.0
# 3      461473883   134195201  265770645     1440   35   F    50.0   160.0
# 4      466389608   160947402  262240911     1440   60   F    52.0   152.0
# ...          ...         ...        ...      ...  ...  ..     ...     ...
# 58810  497537801   130062652  263988404  3909600   50   M    64.0   169.0
# 58811  461252752   126772283  273139806     2880   70   F    53.0   162.0
# 58812  471834474   144363433  275833861     2880   65   F    51.0   152.0
# 58813  419787421   195835964  293939099    12960   85   M    74.0   171.0
# 58814  493136728   148443464  280269654     2880   70   M    78.0   182.0
#
#         race  asa  ...    platelet potassium      sodium total_bilirubin  \
# 0      Asian  NaN  ...         NaN       NaN         NaN             NaN
# 1      Asian  NaN  ...         NaN       NaN         NaN             NaN
# 2      Asian  1.0  ...  215.854671  3.843406  140.403423        0.825000
# 3      Asian  1.0  ...  124.000000  3.900000  138.000000        0.600000
# 4      Asian  1.0  ...  215.854671  3.843406  140.403423        0.825000
# ...      ...  ...  ...         ...       ...         ...             ...
# 58810  Asian  2.0  ...  199.367424  3.500000  136.000000        1.132530
# 58811  Asian  2.0  ...  206.355948  3.700000  142.000000        0.852152
# 58812  Asian  2.0  ...  212.325744  3.800000  143.000000        0.766667
# 58813  Asian  4.0  ...  164.000000  3.900000  137.000000        1.800000
# 58814  Asian  2.0  ...  202.760234  4.067762  138.552948        1.008090
#
#             wbc       LOS is_outlier  icu_visit  or_duration  anesth_duration
# 0           NaN       NaN          1          1        170.0            195.0
# 1           NaN       NaN          0          0        100.0            125.0
# 2      7.995625  3.493056          0          0         70.0             90.0
# 3      6.310000  4.236111          0          0        115.0            150.0
# 4      7.995625  1.607639          0          0         30.0             90.0
# ...         ...       ...        ...        ...          ...              ...
# 58810  9.246938  1.447917          0          0          5.0             25.0
# 58811  8.525825  2.614583          0          0         60.0             75.0
# 58812  8.280235  5.447917          0          0         55.0             75.0
# 58813  9.695000  9.309028          1          1        130.0            170.0
# 58814  9.076454  1.614583          0          0         55.0             70.0
#
# [58815 rows x 63 columns]

# %%
#########################
#
# Export Operations to CSV
#
#########################

df.to_csv('../_data/operations_imputed_CLEAN.csv')
